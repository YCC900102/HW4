# %%
# 導入必要的庫
import pandas as pd
from pycaret.classification import *

# 讀取 Titanic 數據集
train_data = pd.read_csv('train.csv')  # 替換為您的訓練數據文件路徑
test_data = pd.read_csv('test.csv')    # 替換為您的測試數據文件路徑

# 初始化 PyCaret 環境
clf = setup(
    data=train_data,
    target='Survived',
    session_id=42, 
    normalize=True, 
    categorical_features=['Sex', 'Embarked'], 
    ignore_features=['Name', 'Ticket', 'Cabin']
)

# 比較所有可用的分類模型
best_model = compare_models(n_select=1)

# 打印最佳模型名稱
print(f"最佳模型名稱: {type(best_model).__name__}")

# 選擇最佳模型，進行訓練
final_model = finalize_model(best_model)

# 將模型應用於測試集，並生成預測
predictions = predict_model(final_model, data=test_data)

# 打印預測結果的列名，幫助確認
print("預測結果的列名:", predictions.columns)

# 明確指定預測結果的列名（根據 PyCaret 的預設，通常是 'prediction_label'）
if 'prediction_label' in predictions.columns:
    prediction_column = 'prediction_label'
else:
    raise ValueError("找不到包含預測結果的列，請確認模型輸出！")

print(f"使用的預測結果列名為: {prediction_column}")

# Kaggle 提交格式
submission = test_data[['PassengerId']].copy()  # 保留 PassengerId
submission['Survived'] = predictions[prediction_column]  # 使用正確的預測列名

# 確保 Survived 列為整數（0 或 1）
submission['Survived'] = submission['Survived'].astype(int)

# 保存為符合提交格式的 CSV 文件
submission.to_csv('submission.csv', index=False)
print("提交格式的預測結果已保存到 'submission.csv'")
# Out:
# <style type="text/css">
# #T_1b7cc_row11_col1, #T_1b7cc_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1b7cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b7cc_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1b7cc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b7cc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b7cc_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_1b7cc_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1b7cc_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1b7cc_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1b7cc_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_1b7cc_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1b7cc_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_1b7cc_row3_col1" class="data row3 col1" >(891, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1b7cc_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_1b7cc_row4_col1" class="data row4 col1" >(891, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1b7cc_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_1b7cc_row5_col1" class="data row5 col1" >(623, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1b7cc_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_1b7cc_row6_col1" class="data row6 col1" >(268, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1b7cc_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_1b7cc_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1b7cc_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_1b7cc_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1b7cc_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_1b7cc_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1b7cc_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_1b7cc_row10_col1" class="data row10 col1" >79.5%</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1b7cc_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_1b7cc_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1b7cc_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_1b7cc_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1b7cc_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_1b7cc_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1b7cc_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_1b7cc_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1b7cc_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_1b7cc_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1b7cc_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_1b7cc_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1b7cc_row17_col0" class="data row17 col0" >Normalize</td>
#       <td id="T_1b7cc_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1b7cc_row18_col0" class="data row18 col0" >Normalize method</td>
#       <td id="T_1b7cc_row18_col1" class="data row18 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1b7cc_row19_col0" class="data row19 col0" >Fold Generator</td>
#       <td id="T_1b7cc_row19_col1" class="data row19 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_1b7cc_row20_col0" class="data row20 col0" >Fold Number</td>
#       <td id="T_1b7cc_row20_col1" class="data row20 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_1b7cc_row21_col0" class="data row21 col0" >CPU Jobs</td>
#       <td id="T_1b7cc_row21_col1" class="data row21 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_1b7cc_row22_col0" class="data row22 col0" >Use GPU</td>
#       <td id="T_1b7cc_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_1b7cc_row23_col0" class="data row23 col0" >Log Experiment</td>
#       <td id="T_1b7cc_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_1b7cc_row24_col0" class="data row24 col0" >Experiment Name</td>
#       <td id="T_1b7cc_row24_col1" class="data row24 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_1b7cc_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_1b7cc_row25_col0" class="data row25 col0" >USI</td>
#       <td id="T_1b7cc_row25_col1" class="data row25 col1" >515c</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3fb11 th {
#   text-align: left;
# }
# #T_3fb11_row0_col0, #T_3fb11_row0_col2, #T_3fb11_row0_col3, #T_3fb11_row0_col4, #T_3fb11_row1_col0, #T_3fb11_row1_col1, #T_3fb11_row1_col3, #T_3fb11_row1_col5, #T_3fb11_row1_col6, #T_3fb11_row1_col7, #T_3fb11_row2_col0, #T_3fb11_row2_col1, #T_3fb11_row2_col2, #T_3fb11_row2_col3, #T_3fb11_row2_col4, #T_3fb11_row2_col5, #T_3fb11_row2_col6, #T_3fb11_row2_col7, #T_3fb11_row3_col0, #T_3fb11_row3_col1, #T_3fb11_row3_col2, #T_3fb11_row3_col3, #T_3fb11_row3_col4, #T_3fb11_row3_col5, #T_3fb11_row3_col6, #T_3fb11_row3_col7, #T_3fb11_row4_col0, #T_3fb11_row4_col1, #T_3fb11_row4_col2, #T_3fb11_row4_col3, #T_3fb11_row4_col4, #T_3fb11_row4_col5, #T_3fb11_row4_col6, #T_3fb11_row4_col7, #T_3fb11_row5_col0, #T_3fb11_row5_col1, #T_3fb11_row5_col2, #T_3fb11_row5_col3, #T_3fb11_row5_col4, #T_3fb11_row5_col5, #T_3fb11_row5_col6, #T_3fb11_row5_col7, #T_3fb11_row6_col0, #T_3fb11_row6_col1, #T_3fb11_row6_col2, #T_3fb11_row6_col3, #T_3fb11_row6_col4, #T_3fb11_row6_col5, #T_3fb11_row6_col6, #T_3fb11_row6_col7, #T_3fb11_row7_col0, #T_3fb11_row7_col1, #T_3fb11_row7_col2, #T_3fb11_row7_col3, #T_3fb11_row7_col4, #T_3fb11_row7_col5, #T_3fb11_row7_col6, #T_3fb11_row7_col7, #T_3fb11_row8_col0, #T_3fb11_row8_col1, #T_3fb11_row8_col2, #T_3fb11_row8_col3, #T_3fb11_row8_col4, #T_3fb11_row8_col5, #T_3fb11_row8_col6, #T_3fb11_row8_col7, #T_3fb11_row9_col0, #T_3fb11_row9_col1, #T_3fb11_row9_col2, #T_3fb11_row9_col3, #T_3fb11_row9_col4, #T_3fb11_row9_col5, #T_3fb11_row9_col6, #T_3fb11_row9_col7, #T_3fb11_row10_col0, #T_3fb11_row10_col1, #T_3fb11_row10_col2, #T_3fb11_row10_col4, #T_3fb11_row10_col5, #T_3fb11_row10_col6, #T_3fb11_row10_col7, #T_3fb11_row11_col0, #T_3fb11_row11_col1, #T_3fb11_row11_col2, #T_3fb11_row11_col3, #T_3fb11_row11_col4, #T_3fb11_row11_col5, #T_3fb11_row11_col6, #T_3fb11_row11_col7, #T_3fb11_row12_col0, #T_3fb11_row12_col1, #T_3fb11_row12_col2, #T_3fb11_row12_col3, #T_3fb11_row12_col4, #T_3fb11_row12_col5, #T_3fb11_row12_col6, #T_3fb11_row12_col7, #T_3fb11_row13_col0, #T_3fb11_row13_col1, #T_3fb11_row13_col2, #T_3fb11_row13_col3, #T_3fb11_row13_col4, #T_3fb11_row13_col5, #T_3fb11_row13_col6, #T_3fb11_row13_col7 {
#   text-align: left;
# }
# #T_3fb11_row0_col1, #T_3fb11_row0_col5, #T_3fb11_row0_col6, #T_3fb11_row0_col7, #T_3fb11_row1_col2, #T_3fb11_row1_col4, #T_3fb11_row10_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3fb11_row0_col8, #T_3fb11_row1_col8, #T_3fb11_row2_col8, #T_3fb11_row3_col8, #T_3fb11_row4_col8, #T_3fb11_row5_col8, #T_3fb11_row6_col8, #T_3fb11_row7_col8, #T_3fb11_row8_col8, #T_3fb11_row10_col8, #T_3fb11_row11_col8, #T_3fb11_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3fb11_row9_col8, #T_3fb11_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3fb11">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3fb11_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3fb11_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3fb11_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3fb11_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3fb11_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3fb11_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3fb11_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3fb11_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_3fb11_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3fb11_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_3fb11_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_3fb11_row0_col1" class="data row0 col1" >0.8218</td>
#       <td id="T_3fb11_row0_col2" class="data row0 col2" >0.8454</td>
#       <td id="T_3fb11_row0_col3" class="data row0 col3" >0.7033</td>
#       <td id="T_3fb11_row0_col4" class="data row0 col4" >0.8092</td>
#       <td id="T_3fb11_row0_col5" class="data row0 col5" >0.7501</td>
#       <td id="T_3fb11_row0_col6" class="data row0 col6" >0.6132</td>
#       <td id="T_3fb11_row0_col7" class="data row0 col7" >0.6189</td>
#       <td id="T_3fb11_row0_col8" class="data row0 col8" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_3fb11_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_3fb11_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_3fb11_row1_col1" class="data row1 col1" >0.8202</td>
#       <td id="T_3fb11_row1_col2" class="data row1 col2" >0.8577</td>
#       <td id="T_3fb11_row1_col3" class="data row1 col3" >0.6949</td>
#       <td id="T_3fb11_row1_col4" class="data row1 col4" >0.8169</td>
#       <td id="T_3fb11_row1_col5" class="data row1 col5" >0.7463</td>
#       <td id="T_3fb11_row1_col6" class="data row1 col6" >0.6091</td>
#       <td id="T_3fb11_row1_col7" class="data row1 col7" >0.6179</td>
#       <td id="T_3fb11_row1_col8" class="data row1 col8" >0.0230</td>
#     </tr>
#     <tr>
#       <th id="T_3fb11_level0_row2" class="row_heading level0 row2" >knn</th>
#       <td id="T_3fb11_row2_col0" class="data row2 col0" >K Neighbors Classifier</td>
#       <td id="T_3fb11_row2_col1" class="data row2 col1" >0.8074</td>
#       <td id="T_3fb11_row2_col2" class="data row2 col2" >0.8086</td>
#       <td id="T_3fb11_row2_col3" class="data row2 col3" >0.6991</td>
#       <td id="T_3fb11_row2_col4" class="data row2 col4" >0.7822</td>
#       <td id="T_3fb11_row2_col5" class="data row2 col5" >0.7358</td>
#       <td id="T_3fb11_row2_col6" class="data row2 col6" >0.5852</td>
#       <td id="T_3fb11_row2_col7" class="data row2 col7" >0.5898</td>
#       <td id="T_3fb11_row2_col8" class="data row2 col8" >0.2420</td>
#     </tr>
#     <tr>
#       <th id="T_3fb11_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_3fb11_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_3fb11_row3_col1" class="data row3 col1" >0.8026</td>
#       <td id="T_3fb11_row3_col2" class="data row3 col2" >0.8233</td>
#       <td id="T_3fb11_row3_col3" class="data row3 col3" >0.6949</td>
#       <td id="T_3fb11_row3_col4" class="data row3 col4" >0.7706</td>
#       <td id="T_3fb11_row3_col5" class="data row3 col5" >0.7286</td>
#       <td id="T_3fb11_row3_col6" class="data row3 col6" >0.5745</td>
#       <td id="T_3fb11_row3_col7" class="data row3 col7" >0.5784</td>
#       <td id="T_3fb11_row3_col8" class="data row3 col8" >0.0300</td>
#     </tr>
#     <tr>
#       <th id="T_3fb11_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_3fb11_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_3fb11_row4_col1" class="data row4 col1" >0.8010</td>
#       <td id="T_3fb11_row4_col2" class="data row4 col2" >0.8530</td>
#       <td id="T_3fb11_row4_col3" class="data row4 col3" >0.7034</td>
#       <td id="T_3fb11_row4_col4" class="data row4 col4" >0.7651</td>
#       <td id="T_3fb11_row4_col5" class="data row4 col5" >0.7296</td>
#       <td id="T_3fb11_row4_col6" class="data row4 col6" >0.5733</td>
#       <td id="T_3fb11_row4_col7" class="data row4 col7" >0.5775</td>
#       <td id="T_3fb11_row4_col8" class="data row4 col8" >0.2820</td>
#     </tr>
#     <tr>
#       <th id="T_3fb11_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_3fb11_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_3fb11_row5_col1" class="data row5 col1" >0.8010</td>
#       <td id="T_3fb11_row5_col2" class="data row5 col2" >0.8380</td>
#       <td id="T_3fb11_row5_col3" class="data row5 col3" >0.6866</td>
#       <td id="T_3fb11_row5_col4" class="data row5 col4" >0.7702</td>
#       <td id="T_3fb11_row5_col5" class="data row5 col5" >0.7246</td>
#       <td id="T_3fb11_row5_col6" class="data row5 col6" >0.5700</td>
#       <td id="T_3fb11_row5_col7" class="data row5 col7" >0.5734</td>
# 最佳模型名稱: RandomForestClassifier
# 預測結果的列名: Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'prediction_label',
#        'prediction_score'],
#       dtype='object')
# 使用的預測結果列名為: prediction_label
# 提交格式的預測結果已保存到 'submission.csv'
